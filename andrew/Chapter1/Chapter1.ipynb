# %%
# %matplotlib inline
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
import qiskit
# Loading your IBM Q account(s)
IBMQ.load_accounts()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d79eb29b6912> in <module>()
# ----> 1 get_ipython().magic('matplotlib inline')
#       2 # Importing standard Qiskit libraries and configuring account
#       3 from qiskit import QuantumCircuit, execute, Aer, IBMQ
#       4 from qiskit.compiler import transpile, assemble
#       5 from qiskit.tools.jupyter import *
#
# D:\CS-Tools\python jdk\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# ...

# %% [markdown]
# ## Question 1

# %%
qasmCode = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[5];
creg c[5];

h q[0];
cx q[0],q[1];
cx q[0],q[1];
h q[0];
"""
qc = QuantumCircuit.from_qasm_str(qasmCode)
qc.draw()

# %% [markdown]
# This resulted in q0 and q1 both being "0" 100% of time.

# %% [markdown]
# ## Question 2

# %%
import time
backend = IBMQ.backends("ibmqx4")[0]
q = qiskit.QuantumRegister(2)
c = qiskit.ClassicalRegister(2)
qc = qiskit.QuantumCircuit(q, c)
qc.measure(q, c)
job_exp = qiskit.execute(qc, backend=backend)

# %%
from qiskit.tools.visualization import plot_histogram
plot_histogram(job_exp.result().get_counts(qc))

# %% [markdown]
# ## Question 3

# %% [markdown]
# While the result was mostly the same there were slightly different numbers likely due to inaccuracies caused by decoherence.

# %% [markdown]
# ## Question 4

# %% [markdown]
# Such a qubit would lie on the xy-plane of the Bloch sphere.
