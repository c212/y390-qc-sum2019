# %% [markdown]
# 1. Use the Quantum Composer to implement the following circuit:
#     [two qubits: first: CNOT control, measured
#                 second: CNOT target, measured]

# %%
#code generated by IBM QX from Quantum Composer

"""OPENQASM 2.0;
include "qelib1.inc";

qreg q[5];
creg c[5];

h q[0];
cx q[0],q[1];
measure q[0] -> c[0];
measure q[1] -> c[1];"""
# Out:
# 'OPENQASM 2.0;\ninclude "qelib1.inc";\n\nqreg q[5];\ncreg c[5];\n\nh q[0];\ncx q[0],q[1];\nmeasure q[0] -> c[0];\nmeasure q[1] -> c[1];'

# %% [markdown]
# 2. Use the Quantum Composer to implement the XYZS†T†HHTSZY X |"0"〉 circuit.

# %%
"""OPENQASM 2.0;
include "qelib1.inc";

qreg q[5];
creg c[5];

x q[0];
y q[0];
z q[0];
s q[0];
t q[0];
h q[0];
h q[0];
tdg q[0];
sdg q[0];
z q[0];
y q[0];
x q[0];
measure q[0] -> c[0];"""
# Out:
# 'OPENQASM 2.0;\ninclude "qelib1.inc";\n\nqreg q[5];\ncreg c[5];\n\nx q[0];\ny q[0];\nz q[0];\ns q[0];\nt q[0];\nh q[0];\nh q[0];\ntdg q[0];\nsdg q[0];\nz q[0];\ny q[0];\nx q[0];\nmeasure q[0] -> c[0];'

# %% [markdown]
# 3. Use the Quantum Composer to create an input corresponding to the five "01010"
# classical bits.

# %%
"""OPENQASM 2.0;
include "qelib1.inc";

qreg q[5];
creg c[5];

measure q[0] -> c[0];
z q[1];
z q[3];
measure q[4] -> c[4];
measure q[3] -> c[3];
measure q[2] -> c[2];
measure q[1] -> c[1];"""
# Out:
# 'OPENQASM 2.0;\ninclude "qelib1.inc";\n\nqreg q[5];\ncreg c[5];\n\nmeasure q[0] -> c[0];\nz q[1];\nz q[3];\nmeasure q[4] -> c[4];\nmeasure q[3] -> c[3];\nmeasure q[2] -> c[2];\nmeasure q[1] -> c[1];'

# %% [markdown]
# 4. Make a circuit of your own devising, where you know with 100% certainty what
# a simulation should return. Run the simulation.

# %%
#should return 00010
"""OPENQASM 2.0;
include "qelib1.inc";

qreg q[5];
creg c[5];

x q[0];
x q[1];
t q[0];
sdg q[1];
h q[0];
s q[1];
h q[0];
measure q[1] -> c[1];
tdg q[0];
x q[0];
measure q[0] -> c[0];"""
# Out:
# 'OPENQASM 2.0;\ninclude "qelib1.inc";\n\nqreg q[5];\ncreg c[5];\n\nx q[0];\nx q[1];\nt q[0];\nsdg q[1];\nh q[0];\ns q[1];\nh q[0];\nmeasure q[1] -> c[1];\ntdg q[0];\nx q[0];\nmeasure q[0] -> c[0];'
